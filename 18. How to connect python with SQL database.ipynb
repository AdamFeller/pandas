# %% [markdown]
# # 18. How to connect pythob with SQL DataBase

# %% [markdown]
# Source: https://stackoverflow.com/questions/33725862/connecting-to-microsoft-sql-server-using-python

# %%
import pyodbc  
import pandas as pd

COM_cnxn = pyodbc.connect("Driver={SQL Server Native Client 11.0};"
                      "Server=BDPRADA.LACAISSE.COM;"
                      "Database=ADA_CSTAT;"
                      "Trusted_Connection=yes;")

MKT_cnxn = pyodbc.connect("Driver={SQL Server Native Client 11.0};"
                      "Server=BDPRADA.LACAISSE.COM;"
                      "Database=ADA_MB;"
                      "Trusted_Connection=yes;")



company = pd.read_sql_query('select * from dbo.company', COM_cnxn)

MKT = pd.read_sql_query('select * from [cstat_base].[market_cap_monthly]', MKT_cnxn)

# %%
company.head()
# Out:
#     gvkey                                      add1  add2  add3  add4  \
# 0  001000                                      None  None  None  None
# 1  001001                   1924 South Utica Avenue  None  None  None
# 2  001002                         124 Industry Lane  None  None  None
# 3  001003                          7700 Hall Street  None  None  None
# 4  001004  One AAR Place, 1100 North Wood Dale Road  None  None  None
#
#        addzip                                            busdesc         cik  \
# 0        None                                               None        None
# 1       94104                                               None  0000723576
# 2  21030-0126  AAI Corporation, together with its subsidiarie...  0000001745
# 3       63125  A.A. Importing Company, Inc. designs, manufact...  0000730052
# 4       60191  AAR CORP. provides products and services to co...  0000001750
#
#           city                     conm         ...          prican prirow  \
# ...

# %%
MKT.head()
# Out:
#     gvkey   datadate curcdd     mkval  mkval_usd
# 0  001973 1986-10-31    USD  2.836625   2.836625
# 1  001973 1987-09-30    USD  5.528125   5.528125
# 2  001973 1992-02-29    USD  2.448000   2.448000
# 3  001973 1992-04-30    USD  1.836000   1.836000
# 4  001973 1999-08-31    USD  0.230300   0.230300

# %% [markdown]
# ### Concatenate both tables

# %%
company.set_index('gvkey', inplace = True)
MKT.set_index(['gvkey','datadate'], inplace = True)

# %%
MKT.head()
# Out:
#          datadate curcdd     mkval  mkval_usd
# gvkey
# 001973 1986-10-31    USD  2.836625   2.836625
# 001973 1987-09-30    USD  5.528125   5.528125
# 001973 1992-02-29    USD  2.448000   2.448000
# 001973 1992-04-30    USD  1.836000   1.836000
# 001973 1999-08-31    USD  0.230300   0.230300

# %%
company_name = pd.concat([company,MKT], axis = 1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-09cc4bf0d289> in <module>()
# ----> 1 company_name = pd.concat([company,MKT], axis = 1)
#
# C:\Users\fella\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, copy)
#     205                        verify_integrity=verify_integrity,
#     206                        copy=copy)
# --> 207     return op.get_result()
#     208
#     209
#
# C:\Users\fella\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\reshape\concat.py in get_result(self)
#     405             new_data = concatenate_block_managers(
#     406                 mgrs_indexers, self.new_axes, concat_axis=self.axis,
# --> 407                 copy=self.copy)
#     408             if not self.copy:
# ...
